# %%
import pandas as pd

# %%
data_1 = pd.read_csv("crop_production.csv")
data_1
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-06c2d7ea0cd2> in <module>
# ----> 1 data_1[data_1['State_Name']]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
# ...
